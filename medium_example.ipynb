# %%
import os
os.environ['BASE_DIR'] = "<path to cloned FineSurE-ACL24 repo>"
os.environ['OPENAI_API_KEY'] = "Your openai apy key."

# %%
# %%bash
# python "${BASE_DIR}/custom_scripts/keyfacts_extraction.py" \
# --input "${BASE_DIR}/dataset/frank/frank-data-sample-10.json" \
# --openai_key "${OPENAI_API_KEY}" \
# --openai_model "gpt-4o-2024-05-13" \
# --input_type "reference_summary" \
# --examples "${BASE_DIR}/dataset/frank/few-shot_examples.txt"

# %%
# %%bash
# python "${BASE_DIR}/finesure/fact-checking.py" \
# "${BASE_DIR}/dataset/frank/frank-data-sample-10.json" \
# "${BASE_DIR}/fact-checking" \
# "${OPENAI_API_KEY}"
# Out:
# Input ID: b955f7a918fe446c97fd8028e4fd524172a7b5e0 Model Name: bert_sum
# Success: True
# 	[Error Label]: [0, 0, 0]
# 	[Error Type]: ['no error', 'no error', 'no error']
# 	[Faithfulness Score]: 100.0%
#
# Input ID: 137ac0122ef98206953bb24be655f15307345bb7 Model Name: bus
# Success: True
# 	[Error Label]: [0, 1, 0]
# 	[Error Type]: ['no error', 'grammatical error', 'no error']
# 	[Faithfulness Score]: 66.7%
#
# Input ID: 137ac0122ef98206953bb24be655f15307345bb7 Model Name: pgn
# Success: True
# 	[Error Label]: [0, 1, 0]
# 	[Error Type]: ['no error', 'entity error', 'no error']
# 	[Faithfulness Score]: 66.7%
#
# Input ID: 137ac0122ef98206953bb24be655f15307345bb7 Model Name: s2s
# Success: True
# 	[Error Label]: [1, 0, 1]
# 	[Error Type]: ['entity error', 'no error', 'entity error']
# 	[Faithfulness Score]: 33.3%
#
# Input ID: 7bd0f51cb4745f01c3c69c0eead3ec9c5cdebc51 Model Name: bart
# Success: True
# 	[Error Label]: [0, 0]
# 	[Error Type]: ['no error', 'no error']
# ...

# %%
# %%bash
# python "${BASE_DIR}/finesure/keyfact-alignment.py" \
# "${BASE_DIR}/dataset/frank/frank-data-sample-10.json" \
# "${BASE_DIR}/dataset/frank/keyfacts.json" \
# "${BASE_DIR}/keyfact-alignment" \
# "${OPENAI_API_KEY}"
# Out:
# Input ID: b955f7a918fe446c97fd8028e4fd524172a7b5e0 Model Name: bert_sum
# Success: True
# 	[Alignment Label]: [0, 0, 0, 0, 1, 0, 1, 1, 0, 0]
# 	[Matched Sentence Line Numbers]: [1, 3]
# 	[Completeness Score]: 30.0%
# 	[Conciseness Score]: 66.7%
#
# Input ID: 137ac0122ef98206953bb24be655f15307345bb7 Model Name: bus
# Success: True
# 	[Alignment Label]: [0, 1, 1, 1, 1, 0, 0, 0]
# 	[Matched Sentence Line Numbers]: [1, 2]
# 	[Completeness Score]: 50.0%
# 	[Conciseness Score]: 66.7%
#
# Input ID: 137ac0122ef98206953bb24be655f15307345bb7 Model Name: pgn
# Success: True
# 	[Alignment Label]: [0, 1, 1, 1, 0, 0, 0, 0]
# 	[Matched Sentence Line Numbers]: [1, 2]
# 	[Completeness Score]: 37.5%
# 	[Conciseness Score]: 66.7%
#
# Input ID: 137ac0122ef98206953bb24be655f15307345bb7 Model Name: s2s
# Success: True
# 	[Alignment Label]: [0, 0, 1, 0, 0, 0, 0, 0]
# 	[Matched Sentence Line Numbers]: [1]
# 	[Completeness Score]: 12.5%
# 	[Conciseness Score]: 33.3%
#
# ...
